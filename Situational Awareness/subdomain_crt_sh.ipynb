# %%
import requests
import sys

# %%
def get_subdomains(domain: str):
    url = f"https://crt.sh/?q={domain}&output=json"
    try:
        response = requests.get(url, timeout=60) #tends to be slow
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"ERROR: {e}")
        return []

    try:
        data = response.json()
    except ValueError:
        print("Error parsing JSON")
        return []

    subdomains = set()
    for entry in data:
        name_value = entry.get("name_value", "")
        for sub in name_value.split("\n"):  # sometimes multiple names per entry
            if sub.endswith(domain):
                subdomains.add(sub.strip())

    return subdomains

# %%
domain = "uco.es" #University of Cordoba
subs = get_subdomains(domain)

if subs:
    print(f"\nFound {len(subs)} unique subdomains for {domain}:\n")
    for s in subs:
        print(s)
else:
    print(f"No subdomains found")
# Out:
# Found 446 unique subdomains for uco.es:
#
# ws-uxxi-dsr.gestion.uco.es
# www.unityg.san.uco.es
# prestashop.i72marmj.practicas.uco.es
# *.samlidp.uco.es
# www.dev-bullet-is.uco.es
# 0-www.sapd.es.medina.uco.es
# trac-tsuco.webapps.uco.es
# prestashop.i72frcac.practicas.uco.es
# bi-uxxi.gestion.uco.es
# prestashop.i72hepoj.practicas.uco.es
# kaftest.uco.es
# 0-www.nature.com.medina.uco.es
# biblioguias.uco.es
# prestashop.i72leocr.practicas.uco.es
# prestashop.i72cascm.practicas.uco.es
# acceso-uconet.uco.es
# prestashop.i52mahur.practicas.uco.es
# cliente-lucia.gestion.uco.es
# lucia.uco.es
# ucodigital.uco.es
# sicsis02.uco.es
# *.uco.es
# 0-dx.doi.org.medina.uco.es
# prestashop.i62dimap.practicas.uco.es
# papias.papi.uco.es
# *.webapps.uco.es
# prestashop.i62cagoj.practicas.uco.es
# consigna.uco.es
# prestashop.i72cadem.practicas.uco.es
# *.gestion.uco.es
# ucosf02.uco.es
# prestashop.i72rogah.practicas.uco.es
# webmail.uco.es
# mezquita.uco.es
# uxxi-dsr.gestion.uco.es
# prestashop.i72gosem.practicas.uco.es
# www.xcitrix.uco.es
# prestashop.i62cepac.practicas.uco.es
# pfirma.uco.es
# sistemaswiki.gestion.uco.es
# journals.uco.es
# lucia.gestion.uco.es
# elecciones.uco.es
# prestashop.i72arvei.practicas.uco.es
# www.hub.uco.es
# 0-www.engineeringvillage.com.medina.uco.es
# nubarron-aio.uco.es
# uxxirrhh.gestion.uco.es
# onlyofficedocumentserver.uco.es
# fd1gotam@uco.es
# prestashop.i72cuped.practicas.uco.es
# prestashop.i72hocar.practicas.uco.es
# prestashop.i72prbaa.practicas.uco.es
# prestashop.p52mujij.practicas.uco.es
# vrops.ctx.uco.es
# moodledev.priv.uco.es
# identidaddev.uco.es
# 0-search.ebscohost.com.medina.uco.es
# 0-wwwlib.umi.com.medina.uco.es
# nubarron.uco.es
# www.idp.uco.es
# wifiman.uco.es
# www.mandarcorreo-srv.uco.es
# prestashop.i72copal.practicas.uco.es
# 0-www.scopus.com.medina.uco.es
# www.wifiman.uco.es
# dev-bullet-api.uco.es
# prestashop.i72moprf.practicas.uco.es
# prestashop.i72lopca.practicas.uco.es
# hubold.uco.es
# ctxcontrol01.uco.es
# consejo-eps.uco.es
# prestashop.i72gabea.practicas.uco.es
# prestashop.i72bamaa.practicas.uco.es
# www.nodos.uco.es
# appuco.gestion.uco.es
# www.appuco.gestion.uco.es
# www.hub1.uco.es
# unityg.san.uco.es
# www.comrryc.priv.uco.es
# prestashop.i72chibj.practicas.uco.es
# unity.uco.es
# prestashop.i62pepea.practicas.uco.es
# www.elecciones.uco.es
# eadm.gestion.uco.es
# prestashop.i72lutes.practicas.uco.es
# prestashop.i72feurt.practicas.uco.es
# 0-www.iustel.com.medina.uco.es
# ucopress.uco.es
# nextcloud.uco.es
# lists.uco.es
# 0-www.jstor.org.medina.uco.es
# 0-app.vlex.com.medina.uco.es
# ucox.gestion.uco.es
# prestashop.i72caalr.practicas.uco.es
# prestashop.i72samoa.practicas.uco.es
# prestashop.i72orarj.practicas.uco.es
# 0-sabi.bvdinfo.com.medina.uco.es
# lims.uco.es
# 0-link.springer.com.medina.uco.es
# cau.uco.es
# prestashop.i72visac.practicas.uco.es
# *.docencia.uco.es
# 0-gateway.proquest.com.medina.uco.es
# 0-search.proquest.com.medina.uco.es
# ironport1-admin.uco.es
# ldpm.uco.es
# www.dev-bullet-api.uco.es
# prestashop.i62dogaj.practicas.uco.es
# nodos.uco.es
# 0-www.sciencemag.org.medina.uco.es
# www.mezquita.uco.es
# ucoappcrue-staging.webapps.uco.es
# prestashop.i72serij.practicas.uco.es
# portal-uxxi-dsr.gestion.uco.es
# admisiones.online.uco.es
# prestashop.i72recrg.practicas.uco.es
# prestashop.i72malod.practicas.uco.es
# readid-sp.webapps.uco.es
# ucoad03.uco.es
# prestashop.i72marom.practicas.uco.es
# 8085-bddoc.csic.es.medina.uco.es
# cloud-admin.uco.es
# uxxi.gestion.uco.es
# www.sigu.uco.es
# www.consigna.uco.es
# www.sistemaswiki.gestion.uco.es
# prestashop.i52lorag.practicas.uco.es
# satis.gestion.uco.es
# civea.uco.es
# prestashop.fl2pesaa.practicas.uco.es
# www.eadm.gestion.uco.es
# prestashop.i72rumai.practicas.uco.es
# ucosf01.uco.es
# ucoonline.uco.es
# 0-anatomy.tv.medina.uco.es
# comrryc.priv.uco.es
# api-ucocris.uco.es
# relay.uco.es
# www.moodle.uco.es
# prestashop.i52canam.practicas.uco.es
# mebsilpre.ext.uco.es
# pcjau.uco.es
# hub.uco.es
# prestashop.i52gusaj.practicas.uco.es
# www.ucodigitaltv.uco.es
# mandarcorreo2.uco.es
# hub1.uco.es
# cau.info.uco.es
# prestashop.i72roloh.practicas.uco.es
# cloud-aio.uco.es
# pa1.lan.uco.es
# prestashop.i52lepid.practicas.uco.es
# www.eventos.uco.es
# soporte.webapps.uco.es
# *.mebsilpre.ext.uco.es
# imap.uco.es
# www.lims.uco.es
# vega.gestion.uco.es
# bullet-is.uco.es
# prestashop.i72mucua.practicas.uco.es
# priv.uco.es
# aulavirtual.uco.es
# 0-www.tirantasesores.com.medina.uco.es
# *.practicas.uco.es
# identidad.uco.es
# www.bullet-is.uco.es
# www.mandarcorreo2.uco.es
# webapps.uco.es
# asistencia.uco.es
# www.unity.san.uco.es
# registry.uco.es
# ctxsf01.uco.es
# docad01.uco.es
# 0-www.zentralblatt-math.org.medina.uco.es
# prestashop.i72veorj.practicas.uco.es
# *.ctx.uco.es
# dev-bullet-bwp.uco.es
# ucoad02.uco.es
# listas.uco.es
# bi-uxxi-dsr.gestion.uco.es
# www.comrryc.uco.es
# ovirt-temp.priv.uco.es
# pa.lan.uco.es
# db-uxxi-01.gestion.uco.es
# m22momum@uco.es
# 0-ejournals.ebsco.com.medina.uco.es
# unity.priv.uco.es
# nubecilla.uco.es
# moodle.uco.es
# prestashop.i62tomep.practicas.uco.es
# prestashop.i72fellc.practicas.uco.es
# imap1.uco.es
# www.ucas.uco.es
# mailman.uco.es
# onlyoffice.uco.es
# www.leercorreo1.uco.es
# prestashop.i72lulem.practicas.uco.es
# lucia-cliente.gestion.uco.es
# 0-www.uco.es.medina.uco.es
# prestashop.i72alcos.practicas.uco.es
# sa-uxxi-dsr.gestion.uco.es
# www.citrix.uco.es
# 0-apps.webofknowledge.com.medina.uco.es
# comrryc.uco.es
# ldap1.priv.uco.es
# prestashop.i72madoj.practicas.uco.es
# 0-www.emeraldinsight.com.medina.uco.es
# dev-bullet-is.uco.es
# prestashop.cc0luism.practicas.uco.es
# www.appdsr.uco.es
# www.identidad.uco.es
# online.uco.es
# ucoad01.uco.es
# 0-onlinelibrary.wiley.com.medina.uco.es
# winapps.uco.es
# prestashop.in2gasae.practicas.uco.es
# vcenter.priv.uco.es
# prestashop.i72gocao.practicas.uco.es
# *.lucano.uco.es
# 0-journals.sagepub.com.medina.uco.es
# docad02.uco.es
# www3.uco.es
# prestashop.i72pehej.practicas.uco.es
# ws-uxxi-01.gestion.uco.es
# prestashop.i72rogup.practicas.uco.es
# apps.uco.es
# docsf01.uco.es
# www.lucia-cliente.gestion.uco.es
# citrix.uco.es
# prestashop.i62aysac.practicas.uco.es
# www.asistencia.uco.es
# uco.es
# relay1.uco.es
# ironport2-admin.uco.es
# 0-scifinder.cas.org.medina.uco.es
# prestashop.i72jivem.practicas.uco.es
# prestashop.i62frzaa.practicas.uco.es
# prestashop.i72bofea.practicas.uco.es
# sa-uxxi-02.gestion.uco.es
# prestashop.i72micar.practicas.uco.es
# prestashop.i72roloa.practicas.uco.es
# 0-www.sciencedirect.com.medina.uco.es
# ctx.uco.es
# www.mandarcorreo.uco.es
# prestashop.i72lopmv.practicas.uco.es
# serviciosuxxip.gestion.uco.es
# 0-www.ams.org.medina.uco.es
# 0-veterinaryrecord.bmj.com.medina.uco.es
# www.bullet-ns.uco.es
# ironport-admin.uco.es
# nube-aio.uco.es
# *.apps.uco.es
# drive.uco.es
# ucocris.uco.es
# dav.uco.es
# sa-obuxxi-01.gestion.uco.es
# www.dev-bullet-ns.uco.es
# mandarcorreo-srv.uco.es
# jupyterhub.uco.es
# www.ucox.gestion.uco.es
# 0-www.pnas.org.medina.uco.es
# acceso-uconet.lan.uco.es
# sede.uco.es
# nodos.priv.uco.es
# lp.online.uco.es
# bullet-ns.uco.es
# prestashop.i72sefec.practicas.uco.es
# leercorreo1.uco.es
# www.hubold.uco.es
# docencia.uco.es
# 0-ovidsp.ovid.com.medina.uco.es
# prestashop.i72marma.practicas.uco.es
# 0-www.tirantonline.com.medina.uco.es
# sa-uxxi-01.gestion.uco.es
# www5.uco.es
# 0-rmezquita.uco.es.medina.uco.es
# prestashop.i72gogia.practicas.uco.es
# ovirt-temp.uco.es
# commtrust.webapps.uco.es
# kafprod01.uco.es
# www.acceso-uconet.lan.uco.es
# 0-www.annualreviews.org.medina.uco.es
# www.appucoclient.gestion.uco.es
# sirdev1.uco.es
# prestashop.a52hepof.practicas.uco.es
# cib.uco.es
# pcadolfo.uco.es
# bullet-bwp.uco.es
# zoco.uco.es
# prestashop.i72saraf.practicas.uco.es
# prestashop.i72viria.practicas.uco.es
# xedg.gestion.uco.es
# 0-collections.chadwyck.co.uk.medina.uco.es
# prestashop.i72mumam.practicas.uco.es
# www.leercorreo.uco.es
# prestashop.i72roagi.practicas.uco.es
# eventos.uco.es
# ctxcontrol02.uco.es
# *.hpc.uco.es
# www.uco.es
# ovirt.priv.uco.es
# ldp1.uco.es
# trac-ucogranja.webapps.uco.es
# prestashop.i72mepaf.practicas.uco.es
# 0-www.accesowok.fecyt.es.medina.uco.es
# 0-mathscinet.ams.org.medina.uco.es
# medina.uco.es
# prestashop.i72carif.practicas.uco.es
# sello-electronico-test.uco.es
# helvia.uco.es
# serviciosuxxi.gestion.uco.es
# mandarcorreo.uco.es
# ldp.uco.es
# 0-www.eurocarne.com.medina.uco.es
# www.vonecloud.ctx.uco.es
# imap2.uco.es
# *.ext.uco.es
# leercorreo.uco.es
# prestashop.i62pecar.practicas.uco.es
# www.lucano.uco.es
# controldepresencia.priv.uco.es
# *.rrycsic15.uco.es
# wazuh.atdfiware.uco.es
# bullblade01.priv.uco.es
# pepito.uco.es
# 0-ieeexplore.ieee.org.medina.uco.es
# unity.san.uco.es
# xcitrix.uco.es
# drive-admin.uco.es
# prestashop.i72garup.practicas.uco.es
# *.priv.uco.es
# prestashop.i72alllj.practicas.uco.es
# id-uxxi-dsr.gestion.uco.es
# nube.uco.es
# gitlab.uco.es
# prestashop.i72caora.practicas.uco.es
# dev-bullet-ns.uco.es
# 0-www.tandfonline.com.medina.uco.es
# ovirtaux.priv.uco.es
# presencia.uco.es
# rabinf51.uco.es
# nubarron-admin.uco.es
# ldap2.priv.uco.es
# moodledev7.priv.uco.es
# www.bullet-bwp.uco.es
# db-uxxi-dsr.gestion.uco.es
# www.xedg.gestion.uco.es
# uxxi-rdoc-01.gestion.uco.es
# salt.uco.es
# ctxsf02.uco.es
# gestion.uco.es
# www.hub2.uco.es
# www.bullet-api.uco.es
# idp.fed.uco.es
# www.xaulas.uco.es
# 0-www.nnnconsult.com.medina.uco.es
# *.gitlab.uco.es
# prestashop.i62gugaf.practicas.uco.es
# nubecilla-admin.uco.es
# www.vrops.ctx.uco.es
# controldepresencia.uco.es
# cloud.uco.es
# vonecloud.ctx.uco.es
# www.acceso-uconet.uco.es
# prestashop.javier.practicas.uco.es
# relay2.uco.es
# www.mandarcorreo1.uco.es
# prestashop.m42lugor.practicas.uco.es
# hercules.uco.es
# ovirt.uco.es
# lucano.uco.es
# prestashop.i72hisan.practicas.uco.es
# www.dev-bullet-bwp.uco.es
# prestashop.i62liala.practicas.uco.es
# *.atdfiware.uco.es
# idp.uco.es
# prestashop.i72ststd.practicas.uco.es
# bg3mozua@uco.es
# prestashop.i72gimoj.practicas.uco.es
# samlidp.uco.es
# 0-eebo.chadwyck.com.medina.uco.es
# www.gitlab.uco.es
# sigu.uco.es
# ldp2.uco.es
# eadmdsr.gestion.uco.es
# ucodrive.uco.es
# readid-idp.webapps.uco.es
# *.bbdd.uco.es
# leercorreo2.uco.es
# nubecilla-aio.uco.es
# ucodigitaltv.uco.es
# bullet-api.uco.es
# www.gestion.uco.es
# 0-site.ebrary.com.medina.uco.es
# 0-pubs.acs.org.medina.uco.es
# prestashop.i72besad.practicas.uco.es
# prestashop.cc0mufer.practicas.uco.es
# e-administracion.uco.es
# ucoappcrue.webapps.uco.es
# hpc.uco.es
# prestashop.i72catej.practicas.uco.es
# mandarcorreo1.uco.es
# prestashop.i72gogur.practicas.uco.es
# prestashop.i72rabaf.practicas.uco.es
# hub2.uco.es
# 0-www.springerlink.com.medina.uco.es
# www.helvia.uco.es
# appucoclient.gestion.uco.es
# *.dav.uco.es
# aulasoftwarelibre.uco.es
# prestashop.i42lomaf.practicas.uco.es
# jupyterhub.priv.uco.es
# ws-uxxi-02.gestion.uco.es
# proxy.webapps.uco.es
# 0-www.ingebook.com.medina.uco.es
# 0-pld.chadwyck.co.uk.medina.uco.es
# prestashop.i62caroi.practicas.uco.es
# scav.webapps.uco.es
# prestashop.p82fellm.practicas.uco.es
# 0-literature.proquest.com.medina.uco.es
# www.lucia.gestion.uco.es
# uxxi-rdoc-dsr.gestion.uco.es
# pa2.lan.uco.es
# prestashop.cc0mgg.practicas.uco.es
# portal-uxxi.gestion.uco.es
# xaulas.uco.es
# regis.uco.es
# practicas.uco.es
# prestashop.i72bemof.practicas.uco.es
# nube-admin.uco.es
# prestashop.i72coref.practicas.uco.es
# *.online.uco.es
# ucas.uco.es
# www.leercorreo2.uco.es
# appdsr.uco.es
# prestashop.i72cugrj.practicas.uco.es
# prestashop.i72gavem.practicas.uco.es
# 0-inpractice.bmj.com.medina.uco.es
# *.aulasoftwarelibre.uco.es
# prestashop.i72frpeu.practicas.uco.es
# encuestas.webapps.uco.es
# rrycsic15.uco.es
# drive-aio.uco.es
# ext.uco.es
# id-uxxi.gestion.uco.es
