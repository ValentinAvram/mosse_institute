# %%
import pyarrow.parquet as pq
from IPython.display import display

dataset = pq.ParquetDataset('dataset-3/w32processes')
table = dataset.read()

df = table.to_pandas()

print('Student ID: 82R4k2JOBFYpjzrPT6xpDrASy2C3')
# Out:
# Student ID: 82R4k2JOBFYpjzrPT6xpDrASy2C3

# %%
display(df)
# Out:
#      hostname                   name  \
# 0    EB219HPI  modulecoreservice.exe
# 1    EB219HPI           mcshield.exe
# 2    EB219HPI          tvnserver.exe
# 3    EB219HPI            svchost.exe
# 4    EB219HPI              msdtc.exe
# ..        ...                    ...
# 84   WW367BFQ        VBoxService.exe
# 92   WW367BFQ      SearchIndexer.exe
# 94   WW367BFQ            svchost.exe
# 107  WW367BFQ            svchost.exe
# 113  WW367BFQ           McPvTray.exe
#
#                                              arguments             username  \
# 0    "c:\program files\common files\mcafee\moduleco...           vionelso32
# 1    "C:\Program Files\Common Files\McAfee\AMCore\m...           vionelso32
# 2    "C:\Program Files\TightVNC\tvnserver.exe" -con...       victoria.morga
# 3             C:\Windows\system32\svchost.exe -k RPCSS  NT AUTHORITY\SYSTEM
# 4                        C:\Windows\System32\msdtc.exe  NT AUTHORITY\SYSTEM
# ..                                                 ...                  ...
# 84                 C:\Windows\System32\VBoxService.exe  NT AUTHORITY\SYSTEM
# 92    C:\Windows\system32\SearchIndexer.exe /Embedding  NT AUTHORITY\SYSTEM
# 94   C:\Windows\System32\svchost.exe -k LocalServic...  NT AUTHORITY\SYSTEM
# 107      C:\Windows\system32\svchost.exe -k DcomLaunch  NT AUTHORITY\SYSTEM
# 113         "C:\Program Files\McAfee\MAT\McPvTray.exe"         imog.kelly62
#
#                                                 path   pid
# 0    c:\program files\common files\mcafee\modulecore  3970
# 1        C:\Program Files\Common Files\McAfee\AMCore   248
# 2                          C:\Program Files\TightVNC  4715
# 3                                C:\Windows\system32  6432
# 4                                C:\Windows\System32  5828
# ..                                               ...   ...
# 84                               C:\Windows\System32  2008
# 92                               C:\Windows\system32  2472
# 94                               C:\Windows\System32  4880
# 107                              C:\Windows\system32  2220
# 113                      C:\Program Files\McAfee\MAT  2980
#
# [5442 rows x 6 columns]

# %%
import pandas as pd

def group_columns(df, col1, col2, new_col_name):
    df[new_col_name] = df[col1].astype(str) + ' -> ' + df[col2].astype(str)
    return df


new_df = group_columns(df, 'name', 'pid', 'PID-NAME')

display(new_df)
# Out:
#      hostname                   name  \
# 0    EB219HPI  modulecoreservice.exe
# 1    EB219HPI           mcshield.exe
# 2    EB219HPI          tvnserver.exe
# 3    EB219HPI            svchost.exe
# 4    EB219HPI              msdtc.exe
# ..        ...                    ...
# 84   WW367BFQ        VBoxService.exe
# 92   WW367BFQ      SearchIndexer.exe
# 94   WW367BFQ            svchost.exe
# 107  WW367BFQ            svchost.exe
# 113  WW367BFQ           McPvTray.exe
#
#                                              arguments             username  \
# 0    "c:\program files\common files\mcafee\moduleco...           vionelso32
# 1    "C:\Program Files\Common Files\McAfee\AMCore\m...           vionelso32
# 2    "C:\Program Files\TightVNC\tvnserver.exe" -con...       victoria.morga
# 3             C:\Windows\system32\svchost.exe -k RPCSS  NT AUTHORITY\SYSTEM
# 4                        C:\Windows\System32\msdtc.exe  NT AUTHORITY\SYSTEM
# ..                                                 ...                  ...
# 84                 C:\Windows\System32\VBoxService.exe  NT AUTHORITY\SYSTEM
# 92    C:\Windows\system32\SearchIndexer.exe /Embedding  NT AUTHORITY\SYSTEM
# 94   C:\Windows\System32\svchost.exe -k LocalServic...  NT AUTHORITY\SYSTEM
# 107      C:\Windows\system32\svchost.exe -k DcomLaunch  NT AUTHORITY\SYSTEM
# 113         "C:\Program Files\McAfee\MAT\McPvTray.exe"         imog.kelly62
#
#                                                 path   pid  \
# 0    c:\program files\common files\mcafee\modulecore  3970
# 1        C:\Program Files\Common Files\McAfee\AMCore   248
# 2                          C:\Program Files\TightVNC  4715
# 3                                C:\Windows\system32  6432
# 4                                C:\Windows\System32  5828
# ..                                               ...   ...
# 84                               C:\Windows\System32  2008
# 92                               C:\Windows\system32  2472
# 94                               C:\Windows\System32  4880
# 107                              C:\Windows\system32  2220
# 113                      C:\Program Files\McAfee\MAT  2980
#
#                           PID-NAME
# 0    modulecoreservice.exe -> 3970
# 1              mcshield.exe -> 248
# 2            tvnserver.exe -> 4715
# 3              svchost.exe -> 6432
# 4                msdtc.exe -> 5828
# ..                             ...
# 84         VBoxService.exe -> 2008
# 92       SearchIndexer.exe -> 2472
# 94             svchost.exe -> 4880
# 107            svchost.exe -> 2220
# 113           McPvTray.exe -> 2980
#
# [5442 rows x 7 columns]
